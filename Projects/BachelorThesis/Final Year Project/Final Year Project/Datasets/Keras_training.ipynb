# %%
from keras.models import Sequential
from keras.layers import Dense ,Dropout
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical, normalize
# Out:
# Using TensorFlow backend.

# %%
datasets = np.loadtxt('hcc-cleaned-data.csv',delimiter=",")

# %%
X=datasets[:,0:49]

# %%
y = datasets[:,49]

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#scaler.fit(X)
#X_trans =scaler.transform(X)
X[8,:]
# Out:
# array([1.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#        0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 5.000e+01,
#        1.000e+02, 3.200e+01, 1.000e+00, 1.000e+00, 2.000e+00, 3.140e+00,
#        8.800e+00, 1.190e+01, 1.075e+02, 4.900e+00, 7.000e+01, 1.900e+00,
#        3.300e+00, 2.600e+01, 5.900e+01, 1.150e+02, 6.300e+01, 6.100e+00,
#        5.900e-01, 1.000e+00, 6.400e+00, 1.200e+00, 8.500e+01, 7.300e+01,
#        9.820e+02])

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#model = Sequential()

# %%
#model.add(Dense(12,input_dim=11,activation = 'relu'))

# %%
#model.add(Dense(15,activation = 'relu'))

# %%
#model.add(Dense(8,activation = 'relu'))

# %%
#model.add(Dense(10,activation = 'relu'))

# %%
#model.add(Dense(1,activation = 'sigmoid'))

# %%
model = Sequential()
model.add(Dense(64, input_dim=49, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
#model.compile(loss="binary_crossentropy",optimizer="adam", metrics=['accuracy'])

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Anaconda3\envs\deeplearning\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# %%time
model.fit(x_train, y_train,epochs=1000, batch_size=128)
score = model.evaluate(x_test, y_test, batch_size=128)
# Out:
# WARNING:tensorflow:From C:\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1000
# 132/132 [==============================] - 0s 3ms/step - loss: 0.8005 - accuracy: 0.4621
# Epoch 2/1000
# 132/132 [==============================] - 0s 95us/step - loss: 0.7764 - accuracy: 0.4697
# Epoch 3/1000
# 132/132 [==============================] - 0s 98us/step - loss: 0.7791 - accuracy: 0.5076
# Epoch 4/1000
# 132/132 [==============================] - 0s 98us/step - loss: 0.7824 - accuracy: 0.4924
# Epoch 5/1000
# 132/132 [==============================] - 0s 87us/step - loss: 0.7481 - accuracy: 0.5455
# Epoch 6/1000
# 132/132 [==============================] - 0s 98us/step - loss: 0.7173 - accuracy: 0.5227
# Epoch 7/1000
# 132/132 [==============================] - 0s 83us/step - loss: 0.7783 - accuracy: 0.5076
# Epoch 8/1000
# ...

# %%
#model.fit(x_train, y_train, epochs = 1000, batch_size=20, validation_data=(x_test, y_test))

# %%
#model.save('weights.h5')

# %%
#score = model.evaluate(X,y)

# %%
print("\n%s: %.2f%%"%(model.metrics_names[1],score[1]*100))
# Out:
# accuracy: 63.64%

# %%
import math
xnew = np.array([[1.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
       0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
       0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
       1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 5.000e+01,
       1.000e+02, 3.200e+01, 1.000e+00, 1.000e+00, 2.000e+00, 3.140e+00,
       8.800e+00, 1.190e+01, 1.075e+02, 4.900e+00, 7.000e+01, 1.900e+00,
       3.300e+00, 2.600e+01, 5.900e+01, 1.150e+02, 6.300e+01, 6.100e+00,
       5.900e-01, 1.000e+00, 6.400e+00, 1.200e+00, 8.500e+01, 7.300e+01,
       9.820e+02
]])
print(model.predict(xnew))
# Out:
# [[0.32025415]]

# %%
import pandas as pd

# %%
d = pd.read_csv('cir.csv')

# %%
d.columns
# Out:
# Index(['Age ', 'Gender', 'BMI', 'Fever', 'Nausea/Vomting', 'Headache ',
#        'Diarrhea ', 'Fatigue & generalized bone ache ', 'Jaundice ',
#        'Epigastric pain ', 'WBC', 'RBC', 'HGB', 'Plat', 'AST 1', 'ALT 1',
#        'RNA Base', 'Baseline histological Grading',
#        'Baselinehistological staging'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('cir_11.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-a40d57f74e4c> in <module>
# ----> 1 dataset = pd.read_csv('cir_11.csv')
#
# C:\Anaconda3\envs\deeplearning\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
dataset.describe(include='all')

# %%
dataset.info()

# %%
sns.pairplot(dataset,hue='Target')

# %%
sns.heatmap(dataset.corr(), annot=True)
